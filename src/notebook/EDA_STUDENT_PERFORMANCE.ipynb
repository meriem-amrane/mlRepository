# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv('data/stud.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race_ethnicity               1000 non-null   object
#  2   parental_level_of_education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test_preparation_course      1000 non-null   object
#  5   math_score                   1000 non-null   int64
#  6   reading_score                1000 non-null   int64
#  7   writing_score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
'''def replaceCategoricalData(df):
              df.gender.replace({'female':0,'male':1},inplace=True)
              df.parental_level_of_education = LabelEncoder().fit_transform(df.parental_level_of_education)
              df.lunch.replace({'standard':0,'free/reduced':1},inplace=True)
              df.test_preparation_course.replace({'none':0, 'completed':1},inplace=True)
              df.race_ethnicity = LabelEncoder().fit_transform(df.race_ethnicity)
replaceCategoricalData(df)   '''
# Out:
# "def replaceCategoricalData(df):\n              df.gender.replace({'female':0,'male':1},inplace=True)\n              df.parental_level_of_education = LabelEncoder().fit_transform(df.parental_level_of_education)\n              df.lunch.replace({'standard':0,'free/reduced':1},inplace=True)\n              df.test_preparation_course.replace({'none':0, 'completed':1},inplace=True)\n              df.race_ethnicity = LabelEncoder().fit_transform(df.race_ethnicity)\nreplaceCategoricalData(df)   "

# %%
df
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.nunique()
# Out:
# gender                          2
# race_ethnicity                  5
# parental_level_of_education     6
# lunch                           2
# test_preparation_course         2
# math_score                     81
# reading_score                  72
# writing_score                  77
# dtype: int64

# %%
df['total score'] = df['math_score'] + df['reading_score'] + df['writing_score']
df['average'] = df['total score']/3
df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total score    average
# 0          218  72.666667
# 1          247  82.333333
# 2          278  92.666667
# 3          148  49.333333
# ...

# %%
math_full = df[df.math_score == 100].count()[0]
reading_score = df[df.reading_score == 100].count()[0]
writing_score = df[df.reading_score==100].count()[0]
print(f'Number of students with full marks in Maths: {math_full}\n',
      f'number of student with 100 in reading score : {reading_score}\n',
      f'number of student with full mark in writing score :{writing_score}\n')
# Out:
# Number of students with full marks in Maths: 7
#  number of student with 100 in reading score : 17
#  number of student with full mark in writing score :17

# %%
df[df.math_score == 100].count()[0]
# Out:
# 7

# %%
math_less = df[df.math_score <=20].count()[0]
reading_less = df[df.reading_score <=20 ].count()[0]
writing_less = df[df.reading_score <= 20].count()[0]

print(f'Number of students with less than 20 marks in Maths: {math_less}')
print(f'Number of students with less than 20 marks in Writing: {writing_less}')
print(f'Number of students with less than 20 marks in Reading: {reading_less}')
# Out:
# Number of students with less than 20 marks in Maths: 4
# Number of students with less than 20 marks in Writing: 1
# Number of students with less than 20 marks in Reading: 1

# %%
df[df.math_score <=20].count()
# Out:
# gender                         4
# race_ethnicity                 4
# parental_level_of_education    4
# lunch                          4
# test_preparation_course        4
# math_score                     4
# reading_score                  4
# writing_score                  4
# total score                    4
# average                        4
# dtype: int64

# %%
df
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score  \
# ...

# %%
fig,axs = plt.subplots(2,1,figsize=(5,3))
plt.subplot(121)
sns.histplot(data=df,x='average',bins=50,kde=True,color='b')
plt.subplot(122)
sns.histplot(data=df, x='average',hue='gender')
plt.show()
# Out:
# C:\Users\amran\AppData\Local\Temp\ipykernel_17880\754547403.py:2: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(121)

# %%
fig,axs = plt.subplots(2,1,figsize=(5,4))
plt.subplot(121)
sns.histplot(data=df,x='total score',bins=10,kde=True,color='r')
plt.subplot(122)
sns.histplot(data=df,x='total score',hue='gender')
plt.show()
# Out:
# C:\Users\amran\AppData\Local\Temp\ipykernel_17880\1718187193.py:2: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(121)

# %%
df.columns
# Out:
# Index(['gender', 'race_ethnicity', 'parental_level_of_education', 'lunch',
#        'test_preparation_course', 'math_score', 'reading_score',
#        'writing_score', 'total score', 'average'],
#       dtype='object')

# %%
sns.barplot(data=df,x='reading_score',hue='gender')
# Out:
# <Axes: xlabel='reading_score'>

# %%
df.columns
# Out:
# Index(['gender', 'race_ethnicity', 'parental_level_of_education', 'lunch',
#        'test_preparation_course', 'math_score', 'reading_score',
#        'writing_score', 'total score', 'average'],
#       dtype='object')

# %%
sns.barplot(data=df,x='reading_score',hue='gender')
# Out:
# <Axes: xlabel='reading_score'>

# %%
df.columns
# Out:
# Index(['gender', 'race_ethnicity', 'parental_level_of_education', 'lunch',
#        'test_preparation_course', 'math_score', 'reading_score',
#        'writing_score', 'total score', 'average'],
#       dtype='object')

# %%
plt.subplots(1,3,figsize=(15,5))
plt.subplot(141)
sns.histplot(data=df,x='average',kde=True,hue='lunch')
plt.subplot(142)
sns.histplot(data=df[df.gender==0],x='average')
plt.subplot(143)
sns.histplot(data=df[df.gender==0],x='average')
plt.show()
# Out:
# C:\Users\amran\AppData\Local\Temp\ipykernel_17880\2300831018.py:2: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(141)
# C:\Users\amran\AppData\Local\Temp\ipykernel_17880\2300831018.py:4: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(142)
# C:\Users\amran\AppData\Local\Temp\ipykernel_17880\2300831018.py:6: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(143)

# %%
plt.subplots(1,3,figsize=(15,5))
plt.subplot(141)
sns.histplot(data=df,x='average',hue='parental_level_of_education')
plt.subplot(142)
sns.histplot(data=df[df.gender=='female'],x='average',hue='parental_level_of_education')
plt.subplot(143)
sns.histplot(data=df[df.gender=='male'],x='average',kde=True,hue='parental_level_of_education')
plt.show()
# Out:
# C:\Users\amran\AppData\Local\Temp\ipykernel_17880\1282122697.py:2: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(141)
# C:\Users\amran\AppData\Local\Temp\ipykernel_17880\1282122697.py:4: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(142)
# C:\Users\amran\AppData\Local\Temp\ipykernel_17880\1282122697.py:6: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(143)

# %%
df.columns
# Out:
# Index(['gender', 'race_ethnicity', 'parental_level_of_education', 'lunch',
#        'test_preparation_course', 'math_score', 'reading_score',
#        'writing_score', 'total score', 'average'],
#       dtype='object')

# %%
plt.figure(figsize=(18,8))
plt.subplot(1, 4, 1)
plt.title('MATH SCORES')
sns.violinplot(y='math_score',data=df,color='red',linewidth=3)
plt.subplot(1, 4, 2)
plt.title('READING SCORES')
sns.violinplot(y='reading_score',data=df,color='green',linewidth=3)
plt.subplot(1, 4, 3)
plt.title('WRITING SCORES')
sns.violinplot(y='writing_score',data=df,color='blue',linewidth=3)
plt.show()

# %% [markdown]
# From the above three plots its clearly visible that most of the students score in between 60-80 in Maths whereas in reading and writing most of them score from 50-80

# %%
df.columns
# Out:
# Index(['gender', 'race_ethnicity', 'parental_level_of_education', 'lunch',
#        'test_preparation_course', 'math_score', 'reading_score',
#        'writing_score', 'total score', 'average'],
#       dtype='object')

# %% [markdown]
# Multivariate analysis using pieplot

# %%
df.columns
# Out:
# Index(['gender', 'race_ethnicity', 'parental_level_of_education', 'lunch',
#        'test_preparation_course', 'math_score', 'reading_score',
#        'writing_score', 'total score', 'average'],
#       dtype='object')

# %%
plt.rcParams['figure.figsize'] = (60, 12)

plt.subplot(1, 5, 1)
size = df['gender'].value_counts()
labels = 'Female', 'Male'
color = ['red','green']


plt.pie(size, colors = color, labels = labels,autopct = '.%2f%%')
plt.title('Gender', fontsize = 20)
plt.axis('off')



plt.subplot(1, 5, 2)
size = df['race_ethnicity'].value_counts()
labels = 'Group C', 'Group D','Group B','Group E','Group A'
color = ['red', 'green', 'blue', 'cyan','orange']

plt.pie(size, colors = color,labels = labels,autopct = '.%2f%%')
plt.title('Race_Ethnicity', fontsize = 20)
plt.axis('off')



plt.subplot(1, 5, 3)
size = df['lunch'].value_counts()
labels = 'Standard', 'Free'
color = ['red','green']

plt.pie(size, colors = color,labels = labels,autopct = '.%2f%%')
plt.title('Lunch', fontsize = 20)
plt.axis('off')


plt.subplot(1, 5, 4)
size = df['test_preparation_course'].value_counts()
labels = 'None', 'Completed'
color = ['red','green']

plt.pie(size, colors = color,labels = labels,autopct = '.%2f%%')
plt.title('Test Course', fontsize = 20)
plt.axis('off')


plt.subplot(1, 5, 5)
size = df['parental_level_of_education'].value_counts()
labels = 'Some College', "Associate's Degree",'High School','Some High School',"Bachelor's Degree","Master's Degree"
color = ['red', 'green', 'blue', 'cyan','orange','grey']

plt.pie(size, colors = color,labels = labels,autopct = '.%2f%%')
plt.title('Parental Education', fontsize = 20)
plt.axis('off')



plt.tight_layout()
plt.grid()

plt.show()

# %%
f,ax = plt.subplots(1,2,figsize=(20,10))
sns.countplot(x=df.gender,palette='bright',ax=ax[0],saturation=0.75)
for container in ax[0].containers:
    ax[0].bar_label(container,color='red',size=20)
plt.pie(x=df.gender.value_counts(),labels=['Male','Female'],explode=[0,0.1],autopct='%1.1f%%',shadow=True,colors=['#ff4d4d','#ff8000'])
plt.show()
# Out:
# C:\Users\amran\AppData\Local\Temp\ipykernel_17880\3613366284.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df.gender,palette='bright',ax=ax[0],saturation=0.75)

# %% [markdown]
# #BIVARIATE ANALYSIS ( Is Race/Ehnicity has any impact on student's performance ? )

# %%
df.average.mean()
# Out:
# 67.77066666666666

# %%
moyenne = df.groupby('race_ethnicity')['average'].mean()

# %%
df.groupby('race_ethnicity')

# %%
moyenne
# Out:
# race_ethnicity
# group A    62.992509
# group B    65.468421
# group C    67.131661
# group D    69.179389
# group E    72.752381
# Name: average, dtype: float64

# %%
df.race_ethnicity.value_counts().index
# Out:
# Index(['group C', 'group D', 'group B', 'group E', 'group A'], dtype='object', name='race_ethnicity')

# %%
group_data = df.groupby('race_ethnicity')
f,ax= plt.subplots(1,2,figsize=(15,5))
sns.barplot(x=group_data['math_score'].mean().index,y=group_data['math_score'].mean().values,ax=ax[0])
ax[0].set_title('Math score',color='#005ce6',size=20)
for container in ax[0].containers:
    ax[0].bar_label(container,color='black',size=15)
    
sns.barplot(x=group_data['reading_score'].mean().index,y=group_data['reading_score'].mean().values,ax=ax[1])
ax[1].set_title('Reading score')
for container in ax[1].containers:
    ax[1].bar_label(container,color='red',size=16)

# %%
df.columns
# Out:
# Index(['gender', 'race_ethnicity', 'parental_level_of_education', 'lunch',
#        'test_preparation_course', 'math_score', 'reading_score',
#        'writing_score', 'total score', 'average'],
#       dtype='object')

# %% [markdown]
# PARENTAL LEVEL OF EDUCATION COLUMN
# What is educational background of student's parent ?
# Is parental education has any impact on student's performance ?

# %%
df.parental_level_of_education.value_counts()
# Out:
# parental_level_of_education
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: count, dtype: int64

# %%
plt.rcParams['figure.figsize'] = (15, 9)
plt.style.use('fivethirtyeight')
sns.countplot(df['parental_level_of_education'], palette = 'Blues')
plt.title('Comparison of Parental Education', fontweight = 30, fontsize = 20)
plt.xlabel('Degree')
plt.ylabel('count')
plt.show()
# Out:
# C:\Users\amran\AppData\Local\Temp\ipykernel_17880\4115091206.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(df['parental_level_of_education'], palette = 'Blues')

# %%
f,ax=plt.subplots(1,1,figsize=(18,6))
sns.barplot(x=df.groupby('parental_level_of_education')['reading_score'].mean().index,y=df.groupby('parental_level_of_education')['reading_score'].mean().values,ax=ax)
ax.set_title('Math score', color='#005ce6', size=20)
ax.set_xlabel('Mean Math Score', fontsize=12)
ax.set_ylabel('Race/Ethnicity', fontsize=12)
plt.show()

# %%
df.groupby('parental_level_of_education')['reading_score'].agg('mean').plot(kind='barh',figsize=(10,10))
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.subplot(2,2,1)
sns.barplot (x=df['lunch'], y=df['math_score'], hue=df['test_preparation_course'])
plt.subplot(2,2,2)
sns.barplot (x=df['lunch'], y=df['reading_score'], hue=df['test_preparation_course'])
plt.subplot(2,2,3)
sns.barplot (x=df['lunch'], y=df['writing_score'], hue=df['test_preparation_course'])
# Out:
# <Axes: xlabel='lunch', ylabel='writing_score'>

# %%
df.columns
# Out:
# Index(['gender', 'race_ethnicity', 'parental_level_of_education', 'lunch',
#        'test_preparation_course', 'math_score', 'reading_score',
#        'writing_score', 'total score', 'average'],
#       dtype='object')

# %%
plt.subplots(1,4,figsize=(16,5))
plt.subplot(141)
sns.boxplot(df['math_score'],color='skyblue')
plt.subplot(142)
sns.boxplot(df['reading_score'],color='hotpink')
plt.subplot(143)
sns.boxplot(df['writing_score'],color='yellow')
plt.subplot(144)
sns.boxplot(df['average'],color='lightgreen')
plt.show()

# %%
sns.pairplot(df,hue = 'gender')
plt.show()
